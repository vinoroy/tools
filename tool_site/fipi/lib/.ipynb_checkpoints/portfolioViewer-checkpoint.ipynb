# %%
import securities as st
from portfolio import *
from plot import *

# %%
# regular portfolio
#assetList = [{'assetID': 'MFC', 'portfolio': 'Regular', 'assetType': 'COMMON', 'purchaseDate': '2018-02-23', 'purchasePrice': 24.609, 'saleDate': None, 'salePrice': None, 'volume': 700, 'percentOwnership': 1.0, 'priceFeedRef': 'MFC.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'HydroOne', 'portfolio': 'Regular', 'assetType': 'COMMON', 'purchaseDate': '2015-11-05', 'purchasePrice': 20.5, 'saleDate': None, 'salePrice': None, 'volume': 500, 'percentOwnership': 1.0, 'priceFeedRef': 'H.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Rogers', 'portfolio': 'Regular', 'assetType': 'COMMON', 'purchaseDate': '2018-02-16', 'purchasePrice': 58.663, 'saleDate': None, 'salePrice': None, 'volume': 300, 'percentOwnership': 1.0, 'priceFeedRef': 'RCI-B.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Pembina', 'portfolio': 'Regular', 'assetType': 'COMMON', 'purchaseDate': '2018-02-16', 'purchasePrice': 41.486, 'saleDate': None, 'salePrice': None, 'volume': 410, 'percentOwnership': 1.0, 'priceFeedRef': 'PPL.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'BCE', 'portfolio': 'Regular', 'assetType': 'COMMON', 'purchaseDate': '1997-12-12', 'purchasePrice': 2.858, 'saleDate': None, 'salePrice': None, 'volume': 179, 'percentOwnership': 1.0, 'priceFeedRef': 'BCE.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}]

# Amelie portfolio
assetList = [{'assetID': 'Scotia', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 82.81, 'saleDate': None, 'salePrice': None, 'volume': 60, 'percentOwnership': 1.0, 'priceFeedRef': 'BNS.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Royal1', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2014-09-29', 'purchasePrice': 81.1, 'saleDate': None, 'salePrice': None, 'volume': 60, 'percentOwnership': 1.0, 'priceFeedRef': 'RY.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Royal2', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 101.32, 'saleDate': None, 'salePrice': None, 'volume': 50, 'percentOwnership': 1.0, 'priceFeedRef': 'RY.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'TD', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 72.75, 'saleDate': None, 'salePrice': None, 'volume': 70, 'percentOwnership': 1.0, 'priceFeedRef': 'TD.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Enbridge', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 49.03, 'saleDate': None, 'salePrice': None, 'volume': 100, 'percentOwnership': 1.0, 'priceFeedRef': 'ENB.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Fortis', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 47.305, 'saleDate': None, 'salePrice': None, 'volume': 105, 'percentOwnership': 1.0, 'priceFeedRef': 'FTS.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'HydroOne', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 22.41, 'saleDate': None, 'salePrice': None, 'volume': 225, 'percentOwnership': 1.0, 'priceFeedRef': 'H.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'CanadianTire', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 158.38, 'saleDate': None, 'salePrice': None, 'volume': 30, 'percentOwnership': 1.0, 'priceFeedRef': 'CTC-A.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'CP', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 224.42, 'saleDate': None, 'salePrice': None, 'volume': 20, 'percentOwnership': 1.0, 'priceFeedRef': 'CP.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Pembina', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-31', 'purchasePrice': 41.63, 'saleDate': None, 'salePrice': None, 'volume': 121, 'percentOwnership': 1.0, 'priceFeedRef': 'PPL.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Telus', 'portfolio': 'Amelie', 'assetType': 'COMMON', 'purchaseDate': '2017-10-31', 'purchasePrice': 46.71, 'saleDate': None, 'salePrice': None, 'volume': 135, 'percentOwnership': 1.0, 'priceFeedRef': 'T.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}]

# CELI
#assetList = [{'assetID': 'Royal', 'portfolio': 'CELI', 'assetType': 'COMMON', 'purchaseDate': '2014-05-07', 'purchasePrice': 73.09, 'saleDate': None, 'salePrice': None, 'volume': 85, 'percentOwnership': 1.0, 'priceFeedRef': 'RY.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'EMERA', 'portfolio': 'CELI', 'assetType': 'COMMON', 'purchaseDate': '2017-10-31', 'purchasePrice': 48.98, 'saleDate': None, 'salePrice': None, 'volume': 245, 'percentOwnership': 1.0, 'priceFeedRef': 'EMA.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'SNC', 'portfolio': 'CELI', 'assetType': 'COMMON', 'purchaseDate': '2018-02-21', 'purchasePrice': 53.011, 'saleDate': None, 'salePrice': None, 'volume': 120, 'percentOwnership': 1.0, 'priceFeedRef': 'SNC.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'CanadianTire', 'portfolio': 'CELI', 'assetType': 'COMMON', 'purchaseDate': '2017-10-27', 'purchasePrice': 158.5, 'saleDate': None, 'salePrice': None, 'volume': 75, 'percentOwnership': 1.0, 'priceFeedRef': 'CTC-A.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'Loblaw', 'portfolio': 'CELI', 'assetType': 'COMMON', 'purchaseDate': '2014-05-12', 'purchasePrice': 47.43, 'saleDate': None, 'salePrice': None, 'volume': 145, 'percentOwnership': 1.0, 'priceFeedRef': 'L.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}, {'assetID': 'TransCanada', 'portfolio': 'CELI', 'assetType': 'COMMON', 'purchaseDate': '2017-10-31', 'purchasePrice': 60.96, 'saleDate': None, 'salePrice': None, 'volume': 200, 'percentOwnership': 1.0, 'priceFeedRef': 'L.TO', 'priceFeedType': 'YAHOO', 'debtFeedType': None, 'debtFeedRef': None, 'thresholds': None}]

# %%
# load the prtfoliio
myP = Portfolio(assetList)

# %%
myP.getAssetList()
# Out:
# ['Scotia',
#  'Royal1',
#  'Royal2',
#  'TD',
#  'Enbridge',
#  'Fortis',
#  'HydroOne',
#  'CanadianTire',
#  'CP',
#  'Pembina',
#  'Telus']

# %%
myP.upDatePortfolioPriceDataInDB()
# Out:
# getting data for:
# Scotia
# getting data for:
# Royal1
# getting data for:
# Royal2
# getting data for:
# TD
# getting data for:
# Enbridge
# getting data for:
# Fortis
# getting data for:
# HydroOne
# getting data for:
# CanadianTire
# getting data for:
# CP
# getting data for:
# Pembina
# getting data for:
# Telus

# %%
myP.loadPortfolioPriceDataFromDB()

# %% [markdown]
# # Regular portfolio

# %% [markdown]
# ### Portfolio summary table

# %%
# display the summary table of the portfolio
myP.summary
# Out:
#    Pcode      Asset ID Purchase date Purchase price Volume Acquisition  \
# 0    NEG        Scotia    2017-10-27          82.81     60      4968.6
# 1    POS        Royal1    2014-09-29           81.1     60        4866
# 2    POS        Royal2    2017-10-27         101.32     50        5066
# 3    POS            TD    2017-10-27          72.75     70      5092.5
# 4    NEG      Enbridge    2017-10-27          49.03    100        4903
# 5    POS        Fortis    2017-10-27           47.3    105     4967.02
# 6    NEG      HydroOne    2017-10-27          22.41    225     5042.25
# 7    NEG  CanadianTire    2017-10-27         158.38     30      4751.4
# 8    POS            CP    2017-10-27         224.42     20      4488.4
# 9    POS       Pembina    2017-10-31          41.63    121     5037.23
# 10   POS         Telus    2017-10-31          46.71    135     6305.85
# 0    POS         Total                                         55488.3
#
# ...

# %%
# detailed table of the portfolio
myP.detailed
# Out:
#               Market  Est Profit  Acquisition  % Est Profit
# Date
# 2014-05-07   6214.35        1.70      6212.65      0.027364
# 2014-05-08   6224.55       11.90      6212.65      0.191545
# 2014-05-09   6212.65        0.00      6212.65      0.000000
# 2014-05-12  11798.28    -1291.72     13090.00     -9.867991
# 2014-05-13  11802.53    -1287.47     13090.00     -9.835523
# 2014-05-14  11781.11    -1308.89     13090.00     -9.999160
# 2014-05-15  11731.77    -1358.23     13090.00    -10.376089
# 2014-05-16  11684.85    -1405.15     13090.00    -10.734530
# 2014-05-20  11670.67    -1419.33     13090.00    -10.842857
# 2014-05-21  11768.47    -1321.53     13090.00    -10.095722
# 2014-05-22  11835.28    -1254.72     13090.00     -9.585332
# 2014-05-23  11822.85    -1267.15     13090.00     -9.680290
# 2014-05-26  11817.43    -1272.57     13090.00     -9.721696
# 2014-05-27  11847.86    -1242.14     13090.00     -9.489228
# 2014-05-28  11800.46    -1289.54     13090.00     -9.851337
# ...

# %% [markdown]
# ### Portfolio performance plots

# %%
plot_AssetDataVsDates(myP,'Adj Close')
# Out:
# <div id="51024755-617c-4b3c-b840-450e8476d6fc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("51024755-617c-4b3c-b840-450e8476d6fc", [{"mode": "lines", "name": "Royal", "x": ["2014-05-07 04:00:00", "2014-05-08 04:00:00", "2014-05-09 04:00:00", "2014-05-12 04:00:00", "2014-05-13 04:00:00", "2014-05-14 04:00:00", "2014-05-15 04:00:00", "2014-05-16 04:00:00", "2014-05-20 04:00:00", "2014-05-21 04:00:00", "2014-05-22 04:00:00", "2014-05-23 04:00:00", "2014-05-26 04:00:00", "2014-05-27 04:00:00", "2014-05-28 04:00:00", "2014-05-29 04:00:00", "2014-05-30 04:00:00", "2014-06-02 04:00:00", "2014-06-03 04:00:00", "2014-06-04 04:00:00", "2014-06-05 04:00:00", "2014-06-06 04:00:00", "2014-06-09 04:00:00", "2014-06-10 04:00:00", "2014-06-11 04:00:00", "2014-06-12 04:00:00", "2014-06-13 04:00:00", "2014-06-16 
# ...

# %%
plot_AssetDataVsDates(myP,'Est Profit')
# Out:
# <div id="629887be-0d49-4e82-9ffd-96ae7797388d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("629887be-0d49-4e82-9ffd-96ae7797388d", [{"mode": "lines", "name": "Royal", "x": ["2014-05-07 04:00:00", "2014-05-08 04:00:00", "2014-05-09 04:00:00", "2014-05-12 04:00:00", "2014-05-13 04:00:00", "2014-05-14 04:00:00", "2014-05-15 04:00:00", "2014-05-16 04:00:00", "2014-05-20 04:00:00", "2014-05-21 04:00:00", "2014-05-22 04:00:00", "2014-05-23 04:00:00", "2014-05-26 04:00:00", "2014-05-27 04:00:00", "2014-05-28 04:00:00", "2014-05-29 04:00:00", "2014-05-30 04:00:00", "2014-06-02 04:00:00", "2014-06-03 04:00:00", "2014-06-04 04:00:00", "2014-06-05 04:00:00", "2014-06-06 04:00:00", "2014-06-09 04:00:00", "2014-06-10 04:00:00", "2014-06-11 04:00:00", "2014-06-12 04:00:00", "2014-06-13 04:00:00", "2014-06-16 
# ...
